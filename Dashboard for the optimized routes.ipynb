# %% [markdown]
# ## Generated Route, visualization, and dashboard

# %% [markdown]
# This notebook displays the orders to be completed for each driver and generates the dashboard that shows the geographic routes for each driver to complete all the orders.

# %%
import pickle
import folium
import pandas as pd
import numpy as np
import ipywidgets as widgets
from python_file_for_dashboard import create_dashboard, final_result, first_wave,ds
from PIL import Image
routes = final_result

# %%
print('the dashboard cannot be shown because Github does not support displaying Folium dashboard. However, a glimpse of the dashboard is provided below ')
create_dashboard(routes,first_wave,ds)
# Out:
# the dashboard cannot be shown because Github does not support Folium display. However, a glimpse of the dashboard is provided below
# Select a Driver from the below Dropdown:
# interactive(children=(Dropdown(description='Driver Name:', options=('Driver109', 'Driver12', 'Driver130', 'Dri…
# <function dashboard.create_dashboard.<locals>.update_map(driver)>

# %%
image1 = Image.open('dashboard output1.png')
image2 = Image.open('legends.png')
display(image1, image2)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1942x1297>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=2040x223>
